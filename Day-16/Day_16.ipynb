# %% [markdown]
# <a href="https://colab.research.google.com/github/relish-d/DSML/blob/main/Day-16/Day_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = [1,2,3]
it = iter(num)

# %%
print(next(it))
# Out:
# 1

# %%
##iterable
lst = [1,2,3]
for i in lst:
  print(i)
# Out:
# 1
# 2
# 3

# %%
num = [1,2,3]
it = iter(num)

# %%
it

# %%
next(it)
# Out:
# 1

# %%
for i in it:
  print(i)
# Out:
# 2
# 3

# %%
def count_up(n):
  i = 1
  while i<=n:
    yield i
    i+=1

# %%
gent = count_up(3)

# %%
gent
# Out:
# <generator object count_up at 0x7d599fd2a500>

# %%
print(next(gent))
# Out:
# 1

# %%
print(next(gent))
# Out:
# 2

# %%
print(next(gent))
# Out:
# 3

# %%
# try:
# expect
# else:
#   finally:

try:
  numerator = int(input("Enter a number to divide"))
  denominator = int(input("Enter anumber to divide by:"))
  result = numerator/denominator
except ZeroDivisionError:
  print("Error: Cannot divide by zero!")
except ValueError:
  print("Error: Invalid input . Please enter a valid number")
else:
  print(f"The result is {result}")
finally:
  print("Execution complete.")
# Out:
# Enter a number to divide12
# Enter anumber to divide by:6
# The result is 2.0
# Execution complete.

# %%
#ZeroDivisionError

num = 10
result = num/0
print(result)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_723/3211540127.py in <cell line: 0>()
#       2
#       3 num = 10
# ----> 4 result = num/0
#       5 print(result)
#
# ZeroDivisionError: division by zero

# %%
def set(age):
  if age < 0:
    raise ValueError("Age cannot be negative")
  print(f"Age set to {age}")

# %%
try:
  set(5)
except ValueError as e:
  print(e)
# Out:
# Age set to 5

# %%
#custom Expection

class InvalidAgeError(Exception):
  """Custom expection for invalid age values"""
  pass

def set_age_custom(age):
  if age > 120:
    raise InvalidAgeError("age cannnot be over 120")

# %%
set_age_custom(124)
# Out:
# ---------------------------------------------------------------------------
# InvalidAgeError                           Traceback (most recent call last)
# /tmp/ipykernel_723/560963531.py in <cell line: 0>()
# ----> 1 set_age_custom(124)
#
# /tmp/ipykernel_723/2010799196.py in set_age_custom(age)
#       7 def set_age_custom(age):
#       8   if age > 120:
# ----> 9     raise InvalidAgeError("age cannnot be over 120")
#
# InvalidAgeError: age cannnot be over 120
