# %% [markdown]
# <a href="https://colab.research.google.com/github/relish-d/DSML/blob/main/Assignments/ASSIGNMNET_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/relish-d/DSML/blob/main/Assignment/assignment(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day 1 Assignment

# %%
#1 lower()
text = input("Enter a sentence: ")
lower_text = text.lower()
print(lower_text)

# %%
#2 upper
text = input("Enter a sentence: ")
capitalized_text = text.capitalize()
print(capitalized_text)

# %%
#3 capitalize()
text = input("Enter a sentence: ")
capitalized_text = text.capitalize()
print(capitalized_text)

# %%
#4 replace()
text = input("Enter a sentence: ")
old_word = input("Enter a word to replace: ")
new_word = input("Enter a new word: ")
new_text = text.replace(old_word, new_word)
print(new_text)

# %%
#5 strip()
text = input("Enter a sentence: ")
stripped_text = text.strip()
print(stripped_text)

# %%
#6 count()
word = input("Enter a word to count: ")
count = text.count(word)
print(count)

# %%
#7 split()
text = input("Enter a sentence: ")
words = text.split()
print(words)

# %%
#8 find()
word = input("Enter a word to find: ")
position = text.find(word)
print(position)

# %%
#9 count()
text = input("Enter a sentence: ")
word = input("Enter a word to count: ")
count = text.count(word)
print(count)

# %%
#10 isalpha()
text = input("Enter a word: ")
is_alpha = text.isalpha()
print(is_alpha)
