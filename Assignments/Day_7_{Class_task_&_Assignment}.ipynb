# %% [markdown]
# <a href="https://colab.research.google.com/github/relish-d/DSML/blob/main/Assignments/Day_7_%7BClass_task_%26_Assignment%7D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Create a dictionary to store student name, age, and faculty.
# Add a new key called phone to an existing dictionary.
# Update the value of age in a dictionary.
# Remove a key named city from a dictionary using del.
# Check whether the key email exists in a dictionary

# %%
student_dict = {
    "name" : "Relish",
    "age" : 18,
    "faculty" : "Engineering"
}

student_dict["phone"] : 9808558240

student_dict["age"] : 19

student_dict["city"] = "Kathmandu"

del student_dict["city"]

# %%
"email" in student_dict
# Out:
# False

# %%
student_dict
# Out:
# {'name': 'Relish', 'age': 18, 'faculty': 'Engineering'}
