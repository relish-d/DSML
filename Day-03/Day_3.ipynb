# %% [markdown]
# <a href="https://colab.research.google.com/github/relish-d/DSML/blob/main/Day-3/Day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Numbers & Strings

# %%
a = 5

a
# Out:
# 5

# %%
#key value pait
data = {
    "name" : "Ram"
}

data
# Out:
# {'name': 'Ram'}

# %%
a = 5

type(a)
# Out:
# int

# %%
pie = 22/7

pie
# Out:
# 3.142857142857143

# %%
type(pie)
# Out:
# float

# %%
data = 3 + 2j

# %%
data
# Out:
# (3+2j)

# %%
type(data)
# Out:
# complex

# %%
age = 20.4
age = int(age)
age
# Out:
# 20

# %%
income = 2000
new_income = float(income)
new_income
# Out:
# 2000.0

# %%
type(new_income)
# Out:
# float

# %%
3/2
# Out:
# 1.5

# %%
3%2
# Out:
# 1

# %%
5%3
# Out:
# 2

# %%
2**3
# Out:
# 8

# %%
11//3
# Out:
# 3

# %%
a = 3
b = 3
a == b
# Out:
# True

# %%
a !=b
# Out:
# False

# %%
type(a==b)
# Out:
# bool

# %%
import math

# %%
math.floor(44.9)
# Out:
# 44

# %%
math.ceil(44.9)
# Out:
# 45

# %%
import math
math.gcd(18,6,12,9)
# Out:
# 3

# %%
user = 640
capacity = 128
result = max(user, capacity)

# %%
result
# Out:
# 640

# %%
round(22.3345, 2)
# Out:
# 22.33
