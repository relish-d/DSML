# %% [markdown]
# <a href="https://colab.research.google.com/github/relish-d/DSML/blob/main/Day-7/Day_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# tuples and set

# packing and upacking
# tuple operation
#  min max sum index, slicing , concat, repetation, membership, comparision

#  set
#   union intersetion diff, sym diff,  ....

# %%
dict_ = {
    "name" : "Relish",
    "address" : "Lalitpur",
    "phone" : 9808558240
}

# %%
type(dict_)
# Out:
# dict

# %%
dict()

dict_data = dict({
    "name" : "Relish",
    "address" : "Lalitpur",
    "phone" : 9808558240
})

# %%
dict_data
# Out:
# {'name': 'Relish', 'address': 'Lalitpur', 'phone': 9808558240}

# %%
dict_data = dict({
    "name" : "Relish",
    "address" : "Lalitpur",
    "phone" : 9808558240,
    "courses" : ['dsml', 'python','ml']
})

# %%
dict_data
# Out:
# {'name': 'Relish',
#  'address': 'Lalitpur',
#  'phone': 9808558240,
#  'courses': ['dsml', 'python', 'ml']}

# %%
dict_data['name']
# Out:
# 'Relish'

# %%
person = dict([("name", "Relish"), ("Address", "Lalitpur")])
person
# Out:
# {'name': 'Relish', 'Address': 'Lalitpur'}

# %%
dict_new = {
    1: "apple",
    2: "ball"
}

# %%
dict_new
# Out:
# {1: 'apple', 2: 'ball'}

# %%
dict_data = dict({
    "name" : "Relish",
    "address" : "Lalitpur",
    "phone" : 9808558240,
    "courses" : ['dsml', 'python','ml']
})

# %%
dict_data["courses"]
# Out:
# ['dsml', 'python', 'ml']

# %%
dict_data.get("courses")
# Out:
# ['dsml', 'python', 'ml']

# %%
dict_data["phone"] = 9840254255

# %%
dict_data
# Out:
# {'name': 'Relish',
#  'address': 'Lalitpur',
#  'phone': 9840254255,
#  'courses': ['dsml', 'python', 'ml']}

# %%
dict_data.keys()
# Out:
# dict_keys(['name', 'address', 'phone', 'courses'])

# %%
dict_data.values()
# Out:
# dict_values(['Relish', 'Lalitpur', 9840254255, ['dsml', 'python', 'ml']])

# %%
dict_data.items()
# Out:
# dict_items([('name', 'Relish'), ('address', 'Lalitpur'), ('phone', 9840254255), ('courses', ['dsml', 'python', 'ml'])])

# %%
dict_data.pop('address')
# Out:
# 'Lalitpur'

# %%
dict_data
# Out:
# {'address': 'Lalitpur',
#  'phone': 9840254255,
#  'courses': ['dsml', 'python', 'ml']}

# %%
dict_data
# Out:
# {'phone': 9840254255, 'courses': ['dsml', 'python', 'ml']}

# %%
dat_int = {
    1: 12345,
    2: 34567
}

dat_int
# Out:
# {1: 12345, 2: 34567}

# %%
dict_data = dict({
    "name" : "Relish",
    "address" : "Lalitpur",
    "phone" : 9808558240,
    "courses" : ['dsml', 'python','ml']
})

# %%
dict_data.popitem()
# Out:
# ('courses', ['dsml', 'python', 'ml'])

# %%
dict_data
# Out:
# {'name': 'Relish', 'address': 'Lalitpur', 'phone': 9808558240}

# %%
del dict_data['name']

# %%
dict_data
# Out:
# {'address': 'Lalitpur', 'phone': 9808558240}

# %%
dict_data.clear()

# %%
dict_data
# Out:
# {}

# %%
dict_data = dict({
    "name" : "Relish",
    "address" : "Lalitpur",
    "phone" : 9808558240,
    "courses" : ['dsml', 'python','ml']
})

# %%
del dict_data

# %%
dict_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_534/3743155698.py in <cell line: 0>()
# ----> 1 dict_data
#
# NameError: name 'dict_data' is not defined

# %% [markdown]
# delete command lekhesi key ni del hunxa

# %%
dict_ = {
    "name" : "Relish",
    "address" : "Lalitpur",
    "phone" : 9808558240
}

# %%
dict_.pop("name", "Not Found")
# Out:
# 'Relish'

# %%
dict_
# Out:
# {'address': 'Lalitpur', 'phone': 9808558240}

# %%
dict1 = {
    "name" : "Relish",
    "address" : "Lalitpur",
    "age" : 19
}
dict1
# Out:
# {'name': 'Relish', 'address': 'Lalitpur', 'age': 20}

# %%
dict2 = {
   "education" : "+2",
   "home" : "Khokana"
}
dict2
# Out:
# {'education': '+2', 'home': 'Khokana'}

# %%
dict1
# Out:
# {'name': 'Safalta',
#  'address': 'Lalitpur',
#  'age': 18,
#  'education': '+2',
#  'home': 'Khokana'}

# %%
dict3 = {
    "gender" : "Male",
    "marks" : 80
}

# %%
dict1 = {
  "name" : "relish",
  "address" : "lalitpur",
  "age" : 19
}
dict2 = {
  "education" : "+2",
  "home" : "khokana"
}
dict3 = {
  "gender" : "male",
  "marks" : 80
}

# %%
student_dict  = {**dict1, **dict2, **dict3}
student_dict
# Out:
# {'name': 'relish',
#  'address': 'lalitpur',
#  'age': 19,
#  'education': '+2',
#  'home': 'khokana',
#  'gender': 'male',
#  'marks': 80}

# %%
result = sorted(student_dict)
result
# Out:
# ['address', 'age', 'education', 'gender', 'home', 'marks', 'name']

# %%
student = {"b" : 2, "a" : 1, "c" : 3}
result = sorted(student)
result
# Out:
# ['a', 'b', 'c']

# %%
#merge dict
dict1 | dict2 | dict3
# Out:
# {'name': 'relish',
#  'address': 'lalitpur',
#  'age': 19,
#  'education': '+2',
#  'home': 'khokana',
#  'gender': 'male',
#  'marks': 80}

# %%
len(dict1)
# Out:
# 3

# %%
dict_data = ({
    "name" : "Relish",
    "address" : "Lalitpur",
    "phone" : 9808558240,
    "courses" : ['dsml', 'python','ml']
})

# %%
len(dict_data)
# Out:
# 4

# %%
dict_data.setdefault("name", "this is hello")
# Out:
# 'Relish'

# %%
dict_data.keys()
# Out:
# dict_keys(['name', 'address', 'phone', 'courses'])

# %%
dict_data.setdefault("gender", "50")
# Out:
# '50'

# %%
dict_data
# Out:
# {'name': 'Relish',
#  'address': 'Lalitpur',
#  'phone': 9808558240,
#  'courses': ['dsml', 'python', 'ml'],
#  'gender': '50'}

# %%
"status" in dict_data.keys()
# Out:
# False

# %%
"name" in dict_data.keys()
# Out:
# True

# %%
min(dict_data)
# Out:
# 'address'

# %%
dict_ = {
    "A" : 30,
    "B" : 35,
    "c" : 20
}
print(min(dict_.values()))
print(max(dict_.values()))
# Out:
# 20
# 35
