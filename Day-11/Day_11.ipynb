# %% [markdown]
# <a href="https://colab.research.google.com/github/relish-d/DSML/blob/main/Day-11/Day_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello" , "World", sep ="-")
# Out:
# Hello-World

# %%
x = "ram"
print(dir(x))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
def count_vowels(text):
  vowels = "aeiouAEIOU"
  count = 0

  for char in text:
    if char in vowels:
      count += 1
  return count

# %%
count_vowels("Hello World")
# Out:
# 3

# %%
#Hello-World.
print("Hello", "World", sep = "-", end = ".")
# Out:
# Hello-World.

# %%
#implementation date: dd/mm/yyyy

data1 = 16
data2 = "Jul"
data3 = 2026

print(data1, data2, data3, sep = "-")
# Out:
# 16-Jul-2026

# %%
#defining end of line(\n)

print("Hello\nWorld ")
# Out:
# Hello
# World

# %%
#input() to recieve input
name = input("Enter your name")
# Out:
# Enter your namerelish

# %%
#type() to know the type of data
type(1)
# Out:
# int

# %%
#len() to know the no of values

lst = [1,2,3,4,5]
len(lst)
# Out:
# 5

# %%
#dir()
x= "ram"
dir(x)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
file = open("dummy_log.txt", mode = "r")
print(file.read())
# Out:
# [2026-07-17 15:15:53] [WARNING] User authentication successful.
# [2026-07-17 15:15:53] [WARNING] API request completed in 142ms.
# [2026-07-17 15:15:53] [DEBUG] API request completed in 142ms.
# [2026-07-17 15:15:53] [INFO] API request completed in 142ms.
# [2026-07-17 15:15:53] [ERROR] Disk space reaching 88% capacity.
# [2026-07-17 15:15:53] [WARNING] User authentication successful.
# [2026-07-17 15:15:53] [WARNING] Cache flushing completed successfully.
# [2026-07-17 15:15:53] [INFO] Cache flushing completed successfully.
# [2026-07-17 15:15:53] [DEBUG] Failed to load resource: 404 Not Found.
# [2026-07-17 15:15:53] [ERROR] Cache flushing completed successfully.
# [2026-07-17 15:15:53] [WARNING] User authentication successful.
# [2026-07-17 15:15:53] [ERROR] Failed to load resource: 404 Not Found.
# [2026-07-17 15:15:53] [INFO] Failed to load resource: 404 Not Found.
# [2026-07-17 15:15:53] [WARNING] Connection timeout while reaching database.
# ...

# %%
file.close()

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1730/1407933502.py in <cell line: 0>()
# ----> 1 file.read()
#
# ValueError: I/O operation on closed file.

# %%
with open("/dummy_log.txt", mode = "r+") as file:
  file.seek(0) #moves pointer to beginning
  file.write("messi")
  print(file.read())
# Out:
# -07-17 15:15:53] [WARNING] User authentication successful.
# [2026-07-17 15:15:53] [WARNING] API request completed in 142ms.
# [2026-07-17 15:15:53] [DEBUG] API request completed in 142ms.
# [2026-07-17 15:15:53] [INFO] API request completed in 142ms.
# [2026-07-17 15:15:53] [ERROR] Disk space reaching 88% capacity.
# [2026-07-17 15:15:53] [WARNING] User authentication successful.
# [2026-07-17 15:15:53] [WARNING] Cache flushing completed successfully.
# [2026-07-17 15:15:53] [INFO] Cache flushing completed successfully.
# [2026-07-17 15:15:53] [DEBUG] Failed to load resource: 404 Not Found.
# [2026-07-17 15:15:53] [ERROR] Cache flushing completed successfully.
# [2026-07-17 15:15:53] [WARNING] User authentication successful.
# [2026-07-17 15:15:53] [ERROR] Failed to load resource: 404 Not Found.
# [2026-07-17 15:15:53] [INFO] Failed to load resource: 404 Not Found.
# [2026-07-17 15:15:53] [WARNING] Connection timeout while reaching database.
# ...

# %%
for i in range (5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
lst = [1,2,3,4,5,6]
#enumerate
for index, num in enumerate(lst):
  print(num)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
lst = [1,20,3,4,5,6]
#enumerate
for index, num in enumerate(lst):
  # print(f"{num}")
  print(num)
# Out:
# 1
# 20
# 3
# 4
# 5
# 6

# %%
names = ["Rame", "shyam", "Hari", "gita"]
for (i,name) in enumerate(names):
  print(f"{name}:Roll {i}")
# Out:
# Rame:Roll 0
# shyam:Roll 1
# Hari:Roll 2
# gita:Roll 3

# %%
names = ("Rame", "shyam", "Hari", "gita")
for (i,name) in enumerate(names, start=1):
  print(f"{name}:Roll {i}")
# Out:
# Rame:Roll 1
# shyam:Roll 2
# Hari:Roll 3
# gita:Roll 4

# %%
data1 = [1,2,3,4,5]
data2 = ["A","B","C","D","E",]

for (dat,num) in zip(data1,data2):
  print(dat,num, sep="->")
# Out:
# 1->A
# 2->B
# 3->C
# 4->D
# 5->E
