# %% [markdown]
# <a href="https://colab.research.google.com/github/relish-d/DSML/blob/main/Day-17/Day_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sum(a,b):
  # operation
  return a+b

# %%
sum(3,4)
# Out:
# 7

# %%
class Phone:
# Out:
#   File "/tmp/ipykernel_625/791976553.py", line 1
#     class Phone:
#                 ^
# SyntaxError: incomplete input

# %%
# class diagarm
#    - attributes
#     - methods

# %%
class Bike:
  name = ""
  gear = 0

# %%
bike1 = Bike()

# %%
class Vechiles:
  def bus(self, name): #methods
    print("this is the section:", name)
  def truck(self):
    print("hello i am truck")

# %%
obj1 = Vechiles() #object call
obj1.bus("driver")
# Out:
# this is the section: driver

# %%
obj1.truck()
# Out:
# hello i am truck

# %%
class Character:
  def __init__(self, health, damage, speed): #instace method (constructor)
    self.health = health #instance attributes
    self.damage = damage
    self.speed = speed

  def dobule_speed(self): #instance method
    self.speed *=2
    return self.speed

# %%
obj1 = Character(100,50,40)
obj1.speed
# Out:
# 40

# %%
obj1.dobule_speed()
# Out:
# 80

# %%
# shape , color , taste
# using instance calss and instance attributes

# %%
class Product:
  tax_rate = 0.13 #class attributes

  def __init__(self, name, price):
    self.name = name
    self.price = price

# %%
p1 = Product("Laptop", 50000)
p1.tax_rate
# Out:
# 0.13

# %%
p2 = Product("Phone", 200000)
p2.tax_rate
# Out:
# 0.13

# %%
class Calculator:
  #A uitlity function that logically belong to the class but doenot need self or cls
  @staticmethod  #static method
  def add(a,b):
    return a+b

# %%
Calculator.add(3,4)
# Out:
# 7

# %%
class EmailValidator:
  @staticmethod
  def is_valid(email):
    return "@" in email

# %%
EmailValidator.is_valid("test@gmail.com")
# Out:
# True

# %%
#works with the class, not an invidual object
class Student:
  school = "skillshikshya" #class attributes
  @classmethod  #class metthod
  def get_school(cls):
    print(cls.school)

# %%
Student.get_school()
# Out:
# skillshikshya
